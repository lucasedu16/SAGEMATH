# %%
a = plot(x^2 + 2*x + 4, (x, -10, 10), color = 'black', axes_labels = ['$x$', '$y$'])
b = plot(x^2 + 2*x + 4, (x, 0, 5), color = 'red', thickness = 2, fill = true, fillcolor = 'green')
c = text('Área', (2.5, 5), color = 'red')
show(a + b + c)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
a = plot(x^3, (x, -10, 10), ymin = -10, ymax = 10, color = 'blue', ticks = [2, 2], tick_formatter = [2, 2], 
         axes_labels = ['$x$', '$y$'])
b = plot(x^3, (x, -2, 2), ymin = -10, ymax = 10, fill = true, thickness = 1.5, fillcolor = 'gray', color = 'black')
c = text('área', (1.4, 0.5), color = 'black')
d = text('área', (-1.4, -0.5), color = 'black')

coord_vertices = [(2, 0), (2, 8)]
coord_vertices1 = [(-2, 0), (-2, -8)]

show(a + b + c + d + list_plot(coord_vertices, plotjoined = true, thickness = 1.5, linestyle = 'dashed', color = 'green') +
     list_plot(coord_vertices1, plotjoined = true, thickness = 1.5, linestyle = 'dashed', color = 'green'))
# Out:
# Graphics object consisting of 7 graphics primitives
